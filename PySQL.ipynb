# %%
#Connecting Pandas to MySQL

# %%
import pandas as pd
import pymysql

# Database connection
myconnection = pymysql.connect(
    host='127.0.0.1',
    user='root',
    passwd='12345678',
    database='Redbus_Project'
)

# Read and clean CSV data
df = pd.read_csv("bus_routes.csv")
df = df.dropna()  # Drop rows with null values

# Convert pandas dtypes to MySQL types
dtype_mapping = {
    'float64': 'FLOAT',
    'object': 'TEXT',
    'int64': 'INT'
}
column_definitions = ", ".join(
    f"{col} {dtype_mapping[str(dtype)]}" 
    for col, dtype in zip(df.columns, df.dtypes)
)

# Table name
table_name = "Busroutes"

# Create table if it does not exist
with myconnection.cursor() as cursor:
    cursor.execute(f"CREATE TABLE IF NOT EXISTS {table_name} ({column_definitions})")

# Insert data into table
insert_query = f"INSERT INTO {table_name} ({', '.join(df.columns)}) VALUES ({', '.join(['%s'] * len(df.columns))})"
with myconnection.cursor() as cursor:
    cursor.executemany(insert_query, df.values.tolist())
    myconnection.commit()

# Close the connection
myconnection.close()

print("Data inserted successfully")
# Out:
# Data inserted successfully

# %%
result=pd.read_csv("bus_routes.csv")
result
# Out:
#         ID                   Route_Name  \
# 0        1      Vijayawada to Hyderabad
# 1        2      Vijayawada to Hyderabad
# 2        3      Vijayawada to Hyderabad
# 3        4      Vijayawada to Hyderabad
# 4        5      Vijayawada to Hyderabad
# ...    ...                          ...
# 7678  7679  Jammu (j and k) to Amritsar
# 7679  7680  Jammu (j and k) to Amritsar
# 7680  7681  Jammu (j and k) to Amritsar
# 7681  7682  Jammu (j and k) to Amritsar
# 7682  7683  Jammu (j and k) to Amritsar
#
#                                              Route_Link  \
# 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
# ...                                                 ...
# 7678  https://www.redbus.in/bus-tickets/jammu-to-amr...
# 7679  https://www.redbus.in/bus-tickets/jammu-to-amr...
# 7680  https://www.redbus.in/bus-tickets/jammu-to-amr...
# 7681  https://www.redbus.in/bus-tickets/jammu-to-amr...
# 7682  https://www.redbus.in/bus-tickets/jammu-to-amr...
#
#                     Bus_Name                                        Bus_Type  \
# 0              APSRTC - 9356      Super Luxury (Non AC Seater 2+2 Push Back)
# 1              APSRTC - 3858  DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)
# 2             APSRTC - 35269      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 3              APSRTC - 3601      Super Luxury (Non AC Seater 2+2 Push Back)
# 4              APSRTC - 3515      Super Luxury (Non AC Seater 2+2 Push Back)
# ...                      ...                                             ...
# 7678  Vijay Tour and Travels           Bharat Benz A/C Seater /Sleeper (2+1)
# 7679  Vijay Tour and Travels           Bharat Benz A/C Seater /Sleeper (2+1)
# 7680           Lucky Travels          Bharat Benz A/C Seater / Sleeper (2+2)
# 7681      Gajraj bus service                   Bharat Benz A/C Sleeper (2+1)
# 7682          Neeraj travels                      A/C Seater / Sleeper (2+1)
#
#      Departing_Time Duration Reaching_Time  Star_Rating    Price  \
# 0             11:30  06h 35m         18:05          4.0  INR 469
# 1             11:30  05h 00m         16:30          3.7  INR 670
# 2             12:15  06h 10m         18:25          3.7  INR 720
# 3             12:30  08h 05m         20:35          2.5  INR 469
# 4             13:00  08h 00m         21:00          2.0  INR 469
# ...             ...      ...           ...          ...      ...
# 7678          17:15  04h 35m         21:50          2.2      509
# 7679          18:50  04h 50m         23:40          2.2      555
# 7680          23:55  05h 35m         05:30          2.0  INR 279
# 7681          18:30  05h 25m         23:55          3.9  INR 899
# 7682          15:40  04h 32m         20:12          2.5      854
#
#        Seat_Availability
# 0     31 Seats available
# 1     44 Seats available
# 2     24 Seats available
# 3     31 Seats available
# 4     31 Seats available
# ...                  ...
# 7678  14 Seats available
# 7679   6 Seats available
# 7680  39 Seats available
# 7681  20 Seats available
# 7682  26 Seats available
#
# [7683 rows x 11 columns]
